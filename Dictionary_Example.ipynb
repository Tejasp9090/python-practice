# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/python-practice/blob/main/Dictionary_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d={}
type(d)
# Out:
# dict

# %%
d1=dict()
d1
# Out:
# {}

# %%
d.update({'name':'Akash','age':25,'salary':50000})
d
# Out:
# {'name': 'Akash', 'age': 25, 'salary': 50000}

# %%
d2=[{'name_1':'Ketan','age':20},{'name_2':'Shrikant',"age":35}]
d2
# Out:
# [{'name_1': 'Ketan', 'age': 20}, {'name_2': 'Shrikant', 'age': 35}]

# %%
d2[1]
# Out:
# {'name_2': 'Shrikant', 'age': 35}

# %%
{1:100,1:'ABC',1:500}
# Out:
# {1: 500}

# %%
k={100:1,'abc':1,500:1}
k
# Out:
# {100: 1, 'abc': 1, 500: 1}

# %%
k['abc']='xyz'
k
# Out:
# {100: 1, 'abc': 'xyz', 500: 1}

# %%
k['name']='Akshay'
k
# Out:
# {100: 1, 'abc': 'xyz', 500: 1, 'name': 'Akshay'}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'salary'])

# %%
d.values()
# Out:
# dict_values(['Akash', 25, 50000])

# %%
d.items()
# Out:
# dict_items([('name', 'Akash'), ('age', 25), ('salary', 50000)])

# %%
len(d)
# Out:
# 3

# %%
d.setdefault("Rajat")
d
# Out:
# {'name': 'Akash', 'age': 25, 'salary': 50000, 'Rajat': None}

# %%
d.setdefault('Shivam',300)
d
# Out:
# {'name': 'Akash', 'age': 25, 'salary': 50000, 'Rajat': None, 'Shivam': 300}

# %%
d.setdefault('age')
# Out:
# 25
