# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/python-practice/blob/main/Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s="Python is simple programming"
s=s.replace('','')
{char:s.count(char)for char in s}
# Out:
# {'P': 1,
#  'y': 1,
#  't': 1,
#  'h': 1,
#  'o': 2,
#  'n': 2,
#  ' ': 3,
#  'i': 3,
#  's': 2,
#  'm': 3,
#  'p': 2,
#  'l': 1,
#  'e': 1,
#  'r': 2,
#  'g': 2,
#  'a': 1}

# %%
f='I go to pune and pune is good city.I like it much '

# %%
words=f.lower().replace('.','').split()
d={word:words.count(word) for word in words}
print(d)
# Out:
# {'i': 1, 'go': 1, 'to': 1, 'pune': 2, 'and': 1, 'is': 1, 'good': 1, 'cityi': 1, 'like': 1, 'it': 1, 'much': 1}

# %% [markdown]
# **Funcations**

# %%
# Functions without argument
def sample():
  print("Hello all...")

sample()
# Out:
# Hello all...

# %%
# Functions with arguments
# 1)Positional args
def info(name,age,salary):
  print("Your name is:",name)
  print("Your age is:",age)
  print("Your salary is:",salary)

info("Tejas",22,80000)
# Out:
# Your name is: Tejas
# Your age is: 22
# Your salary is: 80000

# %%
info(45000,"Suraj",26)
# Out:
# Your name is: 45000
# Your age is: Suraj
# Your salary is: 26

# %%
#2)Keyword args
info(salary=40000,name="sanket",age=26)
# Out:
# Your name is: sanket
# Your age is: 26
# Your salary is: 40000

# %%
# deafualt args
def info_1(name="Raj",age=24,salary=20000):
  print("Your name is:",name)
  print("Your age is:",age)
  print("Your salary is:",salary)

info_1()
# Out:
# Your name is: Raj
# Your age is: 24
# Your salary is: 20000

# %%
info_1("Tejas",22)
# Out:
# Your name is: Tejas
# Your age is: 22
# Your salary is: 20000

# %%
info_1(age=23,salary=34000)
# Out:
# Your name is: Raj
# Your age is: 23
# Your salary is: 34000

# %%
info_1(name="Vivek",age=23,salary=70000)
# Out:
# Your name is: Vivek
# Your age is: 23
# Your salary is: 70000

# %%
info_1()
# Out:
# Your name is: Raj
# Your age is: 24
# Your salary is: 20000

# %%
def deep_flatten(lst):
    result = []
    for item in lst:
        if isinstance(item, list):
            # Recursively call the function and extend the result
            result.extend(deep_flatten(item))
        else:
            result.append(item)
    return result

# %%
complex_list = [1, [2, [3, 4], 5], 6, [7, 8]]
flat = deep_flatten(complex_list)

print(f"Deeply Nested: {complex_list}")
print(f"Fully Flattened: {flat}")
# Out:
# Deeply Nested: [1, [2, [3, 4], 5], 6, [7, 8]]
# Fully Flattened: [1, 2, 3, 4, 5, 6, 7, 8]
