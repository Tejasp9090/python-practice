# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/python-practice/blob/main/Tuple_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tuple Methods**

# %%
t1=['A','B','C']
t1
# Out:
# ['A', 'B', 'C']

# %%
t2=('A', 'B', 'C')
t2
# Out:
# ('A', 'B', 'C')

# %%
t2[1]=("Omkar")
t2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1177/1769748507.py in <cell line: 0>()
# ----> 1 t2[1]=("Omkar")
#       2 t2
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2.append("Sayalo")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1177/666014758.py in <cell line: 0>()
# ----> 1 t2.append("Sayalo")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
nums=10,20,30,40,50
nums,type(nums)
# Out:
# ((10, 20, 30, 40, 50), tuple)

# %%
even=2,4,6,8
even
# Out:
# (2, 4, 6, 8)

# %%
t3=('A','B','C')
t3
# Out:
# ('A', 'B', 'C')

# %%
ch1,ch2,ch3=t3

# %%
ch2
# Out:
# 'B'

# %%
ch1
# Out:
# 'A'

# %%
ch3
# Out:
# 'C'

# %%
details=("Ujjwala","Nilesh","Phadatare")
details
# Out:
# ('Ujjwala', 'Nilesh', 'Phadatare')

# %%
#unpack
f_name,m_name,l_name=details

# %%
f_name
# Out:
# 'Ujjwala'

# %%
m_name
# Out:
# 'Nilesh'

# %%
l_name
# Out:
# 'Phadatare'

# %%
f_name+' '+l_name
# Out:
# 'Ujjwala Phadatare'
