# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/python-practice/blob/main/set_exa_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s={1,}
type(s)
# Out:
# set

# %%
s1=set()
s1
# Out:
# set()

# %%
type(s1)
# Out:
# set

# %%
#Duplicates Are Not Allowed
s1={1,2,3,1,2,3,1,4,5,6,1,2,3}
s1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# accept Homo/Hetro Values
s2={22.5,22.5,"A","B","A"}
s2
# Out:
# {22.5, 'A', 'B'}

# %%
s2=set()
s2
# Out:
# set()

# %%
s2.add(100)
s2
# Out:
# {100}

# %%
s2.add("python")
s2
# Out:
# {100, 'python'}

# %%
s2.update({'A','B','C',100})
s2
# Out:
# {100, 'A', 'B', 'C', 'python'}

# %%
s2.pop()
s2
# Out:
# {100, 'A', 'B', 'C'}

# %%
s2.remove("C")
s2
# Out:
# {100, 'A', 'B'}

# %%
help(set.remove)
# Out:
# Help on method_descriptor:
#
# remove(self, object, /) unbound builtins.set method
#     Remove an element from a set; it must be a member.
#
#     If the element is not a member, raise a KeyError.

# %%
s2.remove("java")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1740/2310969196.py in <cell line: 0>()
# ----> 1 s2.remove("java")
#
# KeyError: 'java'

# %%
help(set.discard)
# Out:
# Help on method_descriptor:
#
# discard(self, object, /) unbound builtins.set method
#     Remove an element from a set if it is a member.
#
#     Unlike set.remove(), the discard() method does not raise
#     an exception when an element is missing from the set.

# %%
s3={"apple",88,90,88,99,"Orange"}
s3
# Out:
# {88, 90, 99, 'Orange', 'apple'}

# %%
s3.discard("mango")
s3
# Out:
# {88, 90, 99, 'Orange', 'apple'}

# %%
# Union operation
x1={100,200,300}
x2={200,300,400,500}

x1.union(x2) # combining all element
# Out:
# {100, 200, 300, 400, 500}

# %%
# intersection- common elements in both the sets
x1.intersection(x2)
# Out:
# {200, 300}

# %%
x2.difference(x1)
# Out:
# {400, 500}
