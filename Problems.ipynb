# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/python-practice/blob/main/Problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fun_1(arr):
  if not arr:
    return 0

  return arr[0]+fun_1(arr[1:])

print(fun_1([1,2,3,4,5,6]))
# Out:
# 21

# %%
def rotation(s1,s2):
  if len(s1) != len(s2):
    return False
  return s2 in (s1+s2)
print(rotation("Tejas","jasTe"))
# Out:
# True

# %%
#5. Write a Python program to rotate a string to the left by n positions.
S1 = "abcde"
n = 4
result=S1[n:]+ S1[:n]
print(result)
# Out:
# eabcd

# %%
# Given a number n and a digit d, remove one occurrence of
# digit d from n such that the resulting number is maximum.
n = str(input())
d = str(input())
ans = []

for i in range(len(n)):
  if n[i] == d:
    t = n[0:i] + n[(i+1):]
    ans.append(int(t))
print(str(max(ans)))
# Out:
# 1234
# 1
# 234

# %%
#Given a circular array, start from any element and traverse
#all elements either clockwise or anti-clockwise. At every step,
#calculate the cumulative XOR of the elements visited so far.
#Find the maximum possible sum of these cumulative XOR values.
arr = [7,8,5,5,9,2,2,0,1,6]
n = len(arr)
max_val = 0

for start in range(n):
  res = [arr[(start + i) % n] for i in range(n)]
  ans = 0
  total = 0
  for i in res:
    ans ^=i
    total +=ans
  max_val = max(max_val,total)


  res = [arr[(start - i) % n] for i in range(n)]
  ans = 0
  total = 0
  for i in res:
    ans ^=i
    total +=ans
  max_val = max(max_val,total)

print(max_val)

"""arr = [7, 8, 5, 5, 9, 2, 2, 0, 1, 6

7
7 ^ 8
7 ^ 8 ^ 5
7 ^ 8 ^ 5 ^ 5
...
# Out:
# 99

# %%
# Given an array of integers, in one operation
# remove either two elements if they are different, or one
# element if they are equal. Find the minimum number of
# operations required to remove all elements.
n = int(input())
arr = list(map(int,input().split()))

ans = 0
arr.sort()

while len(arr) != 0:
  if arr[0] != arr[-1]:
    arr.pop() # last Element
    arr.pop(0) # first element
  else:
    arr.pop(0)
  ans+=1
print(ans)


"""[1,2,3,4,5]
 ↓ remove 1 and 5
[2,3,4]
 ↓ remove 2 and 4
[3]
 ↓ remove 3
[]"""
# Out:
# 5
# 2 2 3 3 1
# 3

# %%
# Import a test Module here

import test

# %%
test.place
# Out:
# 'Karad'

# %%
test.name
# Out:
# 'Tejas'

# %%
test.info()
# Out:
# This Is The Test Module

# %%
import test as t

# %%
t.name
# Out:
# 'Tejas'

# %%
t.info()
# Out:
# This Is The Test Module

# %%
t.info()
# Out:
# This is Test Module

# %%
t.info()
# Out:
# This is Test Module

# %%
t.info()
# Out:
# This Is The Test Module

# %%
t.degree
# Out:
# 'B.tech'

# %%
pip install qrcode[pil]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.9 MB/s eta 0:00:00
# ...

# %%
pip show qrcode
# Out:
# Name: qrcode
# Version: 8.2
# Summary: QR Code image generator
# Home-page: https://github.com/lincolnloop/python-qrcode
# Author: Lincoln Loop
# Author-email: info@lincolnloop.com
# License: BSD
# Location: /usr/local/lib/python3.13/dist-packages
# Requires:
# Required-by:

# %%
import qrcode

data=input("Enter your data:")

qr = qrcode.make(data)

# Save the QR Code as an image
qr.save("basic_qr_code.png")
# Out:
# Enter your data:https://github.com/Tejasp9090?tab=overview&from=2026-08-01&to=2026-08-31

# %%
pip install pyttsx3

# %%
pip install gtts
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.5.0
#     Uninstalling click-8.5.0:
#       Successfully uninstalled click-8.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wandb 0.28.1 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# huggingface-hub 1.28.0 requires click<9.0.0,>=8.4.2, but you have click 8.1.8 which is incompatible.
# spacy 3.8.16 requires click<9.0.0,>=8.2.1, but you have click 8.1.8 which is incompatible.
# ...

# %%
from gtts import gTTS
import os
mytext = 'namstee ! Welcome to Python Programming!'
language = 'en'
myobj = gTTS(text=mytext, lang=language, slow=False)
myobj.save("welcome.mp3")
os.system("start welcome.mp3")
# Out:
# 32512

# %%
from IPython.display import Audio
Audio('welcome.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Image
Image('basic_qr_code.png')
