# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/python-practice/blob/main/List_exa_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=["Tejas","Nilesh","Phadatare"]
a
# Out:
# ['Tejas', 'Nilesh', 'Phadatare']

# %%
a.append("Final_year")
a
# Out:
# ['Tejas', 'Nilesh', 'Phadatare', 'Final_year']

# %%
a.extend("CSBS")
a
# Out:
# ['Tejas', 'Nilesh', 'Phadatare', 'Final_year', 'C', 'S', 'B', 'S']

# %%
a.pop()
a
# Out:
# ['Tejas', 'Nilesh', 'Phadatare', 'Final_year', 'C', 'S', 'B']

# %%
a[0]
a
# Out:
# [10, 20, 30]

# %%
a[0]
# Out:
# 'Tejas'

# %%
a[0]="Rutuja"

# %%
a
# Out:
# ['Rutuja', 'Nilesh', 'Phadatare', 'Final_year', 'C', 'S', 'B']

# %%
a[0:1]
# Out:
# ['Rutuja']

# %%
a[0:4]
# Out:
# ['Rutuja', 'Nilesh', 'Phadatare', 'Final_year']

# %%
x=[1,2,3,4,5,6]
x
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x.insert(1,"Tejaas")
x
# Out:
# [1, 'Tejaas', 2, 3, 4, 5, 6]

# %%
x.reverse()
x
# Out:
# [6, 5, 4, 3, 2, 'Tejaas', 1]

# %%
b=[1,20,10,55,12,78]
b
# Out:
# [1, 20, 10, 55, 12, 78]

# %%
b.sort()
b
# Out:
# [1, 10, 12, 20, 55, 78]

# %%
b.index(1)
b
# Out:
# [1, 10, 12, 20, 55, 78]

# %%
b.sort(reverse=True)
b
# Out:
# [78, 55, 20, 12, 10, 1]

# %%
a=[10,20,30]
a
# Out:
# [10, 20, 30]

# %%
b=a.copy()
b
# Out:
# [10, 20, 30]

# %%
b.append('c++')
b
# Out:
# [10, 20, 30, 'c++']

# %%
a
# Out:
# [10, 20, 30]

# %%
id(a),id(b)
# Out:
# (139234619007168, 139234051005888)

# %%
c=a.copy()
c
# Out:
# [10, 20, 30, [100, 200]]

# %%
c[-1].append("Sayali")

# %%
a
# Out:
# [10, 20, 30, [100, 200, 'Sayali']]

# %%
#deep  copy example
t=[10,20,30]
t
# Out:
# [10, 20, 30]

# %%
d=t
d
# Out:
# [10, 20, 30]

# %%
d.append("Era")
d
# Out:
# [10, 20, 30, 'Era']

# %%
t
# Out:
# [10, 20, 30, 'Era']

# %%
id(d),id(t)
# Out:
# (140114170436160, 140114170436160)
