# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/python-practice/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = ("I", "1", "Live", "2", "in", "3", "India")

result=""

for x in s:
  if not x.isdigit():
    result += x + " "

print(result)
# Out:
# I Live in India

# %%
k = [1, 2, 3, 4]

k[0], k[-1] = k[-1], k[0]
print(k)
# Out:
# [4, 2, 3, 1]

# %%
x=10
y=20
x,y=y,x
print(x,y)
# Out:
# 20 10

# %%
items = ["Python", "", "AI", "", "ML", "Data"]

result = []
for item in items:
    if item:
        result.append(item)

print(result)

list(filter(None,items))
# Out:
# ['Python', 'AI', 'ML', 'Data']
# ['Python', 'AI', 'ML', 'Data']

# %%
list(filter(None,items))
# Out:
# ['Python', 'AI', 'ML', 'Data']

# %%
num = int(input("Enter a number: "))

for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
# Enter a number: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
employees = [
{"name": "Amit", "salary": 45000},
{"name": "Neha", "salary": 60000},
{"name": "Ravi", "salary": 38000}
]

result = sorted(employees, key=lambda emp: emp["salary"])
print(result)
# Out:
# [{'name': 'Ravi', 'salary': 38000}, {'name': 'Amit', 'salary': 45000}, {'name': 'Neha', 'salary': 60000}]

# %%
num = int(input("Enter a number: "))
r = range(1, 11)
list(map(lambda w: w*num, r))
# Out:
# Enter a number: 5
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
employees = [
{"name": "Amit", "salary": 45000},
{"name": "Neha", "salary": 60000},
{"name": "Ravi", "salary": 38000}
]

result = sorted(employees, key=lambda emp: emp["salary"],reverse=True)
print(result)
# Out:
# [{'name': 'Neha', 'salary': 60000}, {'name': 'Amit', 'salary': 45000}, {'name': 'Ravi', 'salary': 38000}]

# %%
a = [3, 1, 2]

a.sort()

print(a)
# Out:
# [1, 2, 3]
