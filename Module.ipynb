# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/python-practice/blob/main/Module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10

# %%
a="Tejas"
a
# Out:
# 'Tejas'

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.factorial(7)
# Out:
# 5040

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.cos(8)
# Out:
# -0.14550003380861354

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import math as m

# %%
m.sin(4)
# Out:
# -0.7568024953079282

# %%
m.sqrt(25)
# Out:
# 5.0

# %%
m.factorial(6)
# Out:
# 720

# %%
from math import factorial,pi

# %%
factorial(7)
# Out:
# 5040

# %%
pi
# Out:
# 3.141592653589793

# %%
from math import *

# %%
pi
# Out:
# 3.141592653589793

# %%
sqrt(25)
# Out:
# 5.0

# %%
factorial(5)
# Out:
# 120

# %%
e
# Out:
# 2.718281828459045

# %%
sin(80)
# Out:
# -0.9938886539233752
