# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/python-practice/blob/main/lambda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
check = lambda name:name.upper()
check("yogesh")
# Out:
# 'YOGESH'

# %%
test = lambda num: '+ve' if num>0 else  '-ve'
test(-9)
# Out:
# '-ve'

# %%
# Higher Order Functions

# %%
# map Operation
salary = [1000,2000,3000,4000,5000]

list(map(lambda sal:sal+sal*.1,salary))
# Out:
# [1100.0, 2200.0, 3300.0, 4400.0, 5500.0]

# %%
salary
# Out:
# [1000, 2000, 3000, 4000, 5000]

# %%
def test(sal):
  if sal<3000:
    return sal + sal*.1
  elif sal == 3000:
    return sal
  else:
    return sal + sal *.2

list(map(test,salary))
# Out:
# [1100.0, 2200.0, 3000, 4800.0, 6000.0]

# %%
# Filter Operation..
tuple(filter(lambda sal:sal>2500,salary))
# Out:
# (3000, 4000, 5000)

# %%
tuple(filter(lambda sal:(sal>2500) or (sal==1000),salary))
# Out:
# (1000, 3000, 4000, 5000)

# %%
# reduce Operation
from functools import reduce

# %%
data=[1,2,3,4,5]
reduce(lambda x,y:x+y,data)
# Out:
# 15

# %%
data
# Out:
# [1, 2, 3, 4, 5]

# %%
list(filter(lambda num:num%2!=0,data))
# Out:
# [1, 3, 5]

# %%
list(map(lambda num:num%2!=0,data))
# Out:
# [True, False, True, False, True]

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.factorial(5)
# Out:
# 120

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
import math as m

# %%
m.e
# Out:
# 2.718281828459045

# %%
m.sqrt(100)
# Out:
# 10.0

# %%
m.pi
# Out:
# 3.141592653589793

# %%
from math import factorial,pi

# %%
pi
# Out:
# 3.141592653589793

# %%
factorial(6)
# Out:
# 720
