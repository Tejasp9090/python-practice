# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/python-practice/blob/main/if_elif_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if True:
  print("Inside The Block")
print("Out Side The Block")
# Out:
# Inside The Block
# Out Side The Block

# %%
if False:
  print("Inside The Block")
print("Out Side The Block")
# Out:
# Out Side The Block

# %%
num=int(input("Enter The Number.:"))

if num > 0:
  print(num, 'is +ve')
else:
  print(num, 'is -ve')
# Out:
# Enter The Number.:0
# 0 is -ve

# %%
num=0
if num == 0:
  print("Its 0: Neither +ve/-ve")
elif num > 0:
  print(num, 'is +ve')
else:
  print(num, 'is -ve')
# Out:
# Its 0: Neither +ve/-ve

# %%
branch=input("Enter Your Branch: ")
pin =int(input("Enter The Pin: "))

if branch == 'sbi' and pin == 1234:
  print("Login succesfuly..")
else:
  print("Something Wrong ...pls Try again..")
# Out:
# Enter Your Branch: bom
